# %%
from gensim.models import KeyedVectors

model = KeyedVectors.load("chive-1.2-mc90_gensim/chive-1.2-mc90.kv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from gensim.models import KeyedVectors
# ----> 3 model = KeyedVectors.load("chive-1.2-mc90_gensim/chive-1.2-mc90.kv")
#       5 print(model.most_similar("猫"))
#
# File ~/Documents/GitHub/Natural_Language_Analysis/.venv/lib/python3.12/site-packages/gensim/utils.py:485, in SaveLoad.load(cls, fname, mmap)
#     481 logger.info("loading %s object from %s", cls.__name__, fname)
#     483 compress, subname = SaveLoad._adapt_by_suffix(fname)
# --> 485 obj = unpickle(fname)
#     486 obj._load_specials(fname, mmap, compress, subname)
#     487 obj.add_lifecycle_event("loaded", fname=fname)
#
# File ~/Documents/GitHub/Natural_Language_Analysis/.venv/lib/python3.12/site-packages/gensim/utils.py:1459, in unpickle(fname)
#    1445 def unpickle(fname):
# ...

# %%
print(model.most_similar("猫"))
